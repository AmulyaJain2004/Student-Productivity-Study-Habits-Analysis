# %%
import requests
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import json
import pandas as pd

# %%
df = pd.read_csv('synthetic_student_data.csv')
df
# Out:
#      student_id  year_of_study  major study_hours_per_day  \
# 0             1              4   SOLS                 3-4
# 1             2              5    SOL                 3-4
# 2             3              3   SOCS                 1-2
# 3             4              5   SOLS                 3-4
# 4             5              5    SOD   More than 6 hours
# ..          ...            ...    ...                 ...
# 495         496              1    SOL                 3-4
# 496         497              3    SOL                 1-2
# 497         498              1    SOB                 1-2
# 498         499              1    SOL                 5-6
# 499         500              1  SOHST                 1-2
#
#                                study_schedule  \
# 0                               Weekends only
# 1                               Weekends only
# 2                         Daily study routine
# 3                               Weekends only
# ...

# %%
df.shape
# Out:
# (500, 30)

# %%
df.describe()
# Out:
#        student_id  year_of_study  focus_level         gpa  productivity_level  \
# count  500.000000     500.000000   500.000000  500.000000          500.000000
# mean   250.500000       2.970000     5.488000    4.927580            5.406000
# std    144.481833       1.425891     2.824502    2.932527            2.938441
# min      1.000000       1.000000     1.000000    0.000000            1.000000
# 25%    125.750000       2.000000     3.000000    2.270000            3.000000
# 50%    250.500000       3.000000     5.000000    4.875000            6.000000
# 75%    375.250000       4.000000     8.000000    7.500000            8.000000
# max    500.000000       5.000000    10.000000    9.970000           10.000000
#
#        stress_level  job_confidence
# count    500.000000      500.000000
# mean       5.588000        5.528000
# std        2.860528        2.900697
# min        1.000000        1.000000
# 25%        3.000000        3.000000
# 50%        6.000000        6.000000
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 500 entries, 0 to 499
# Data columns (total 30 columns):
#  #   Column                                Non-Null Count  Dtype
# ---  ------                                --------------  -----
#  0   student_id                            500 non-null    int64
#  1   year_of_study                         500 non-null    int64
#  2   major                                 500 non-null    object
#  3   study_hours_per_day                   500 non-null    object
#  4   study_schedule                        500 non-null    object
#  5   study_environment                     500 non-null    object
#  6   focus_level                           500 non-null    int64
#  7   gpa                                   500 non-null    float64
#  8   avg_sleep_hours                       500 non-null    object
#  9   sleep_quality                         500 non-null    object
#  10  productivity_level                    500 non-null    int64
# ...

# %%
df.isnull().sum()
# Out:
# student_id                              0
# year_of_study                           0
# major                                   0
# study_hours_per_day                     0
# study_schedule                          0
# study_environment                       0
# focus_level                             0
# gpa                                     0
# avg_sleep_hours                         0
# sleep_quality                           0
# productivity_level                      0
# sleep_disruption                        0
# stress_level                            0
# stress_factors                          0
# frequency_of_overwhelm                  0
# relaxation_techniques                   0
# social_media_hours                      0
# social_media_impact                     0
# social_media_platforms                  0
# extracurricular_participation           0
# extracurricular_hours                   0
# extracurricular_impact                  0
# ...

# %%
# # features we have to convert to category 23-03-2025
# category_features = ["year_of_study", 
#                      "major", 
#                      "study_schedule", "study_environment", 
#                      "sleep_quality", "sleep_disruption", 
#                      "stress_factors", "frequency_of_overwhelm", "relaxation_techniques",
#                      "social_media_hours", "social_media_impact", 
#                      "extracurricular_participation", "extracurricular_hours", "extracurricular_impact", "extracurricular_impact_stress_levels",
#                      "career_preparedness", "internship_experience", 
#                      "part_time_job", "financial_stress", "financial_stress_impact"]  
# # treat social_media_platforms separately 
# len (category_features)

# %%
# ordinal_features = [
#     "study_hours_per_day", 
#     "avg_sleep_hours",
#     "sleep_quality",
#     "social_media_hours",
#     "career_preparedness",
#     "frequency_of_overwhelm",
#     "financial_stress_impact"
# ]
# len(ordinal_features)

# %%
# one_hot_features = [
#     "year_of_study", "major", 
#     "study_schedule", "study_environment", 
#     "sleep_disruption", 
#     "relaxation_techniques", 
#     "social_media_impact", 
#     "extracurricular_participation", "extracurricular_hours", "extracurricular_impact", "extracurricular_impact_stress_levels",
#     "internship_experience", 
#     "part_time_job", "work_hours_per_week", "financial_stress"
# ]
# len(one_hot_features)

# %%
# multi_label_features = [
#     "social_media_platforms",   # A student can use multiple platforms
#     "stress_factors"            # A student can have multiple stress factors
# ]
# len(multi_label_features)

# %%
# numerical_features = [
#     "focus_level", 
#     "gpa", 
#     "productivity_level", 
#     "stress_level", 
#     "job_confidence"
# ]
# len(numerical_features)  # 6

# %%
for i in df.columns:
    print(i)
# Out:
# student_id
# year_of_study
# major
# study_hours_per_day
# study_schedule
# study_environment
# focus_level
# gpa
# avg_sleep_hours
# sleep_quality
# productivity_level
# sleep_disruption
# stress_level
# stress_factors
# frequency_of_overwhelm
# relaxation_techniques
# social_media_hours
# social_media_impact
# social_media_platforms
# extracurricular_participation
# extracurricular_hours
# extracurricular_impact
# extracurricular_impact_stress_levels
# career_preparedness
# internship_experience
# job_confidence
# part_time_job
# work_hours_per_week
# financial_stress
# financial_stress_impact

# %%
to_num_features = ["study_hours_per_day",
                   "focus_level",
                   "gpa",
                   ]
